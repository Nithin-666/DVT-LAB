# %%
url = 'https://github.com/Nithin-666/Data-visualization-experiments/blob/main/exp_2DVT.ipynb'
print(f"The extracted URL is: {url}")
# Out:
# The extracted URL is: https://github.com/Nithin-666/Data-visualization-experiments/blob/main/exp_2DVT.ipynb
